# %% [markdown]
# # Assignment 3: EEG and Event-Related Potentials
# The assignment will introduce you to EEG brain data, as well as some of the techniques and methods used to analyze it.

# %%
# imports
import pandas as pd
import cmlreaders as cml
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Working with EEG data
# We learned how to load basic information about CML experiments and experimental events in assignment 1. Next, we're going to load EEG/iEEG data that correspond to those events.

# %% [markdown]
# ## Question 1: Electrodes in the Brain
# For this question, we will use the term "electrode" to refer to individual contacts, as opposed to bipolar referenced virtual "electrodes".  In other words, use the contacts dataframe (not the pairs dataframe) to answer the following. **Note that here were are loading intracranial data.**
#
# 1) How many electrodes does R1111M have placed in the temporal cortex? (Hint: Anything that contains temporal)
# 2) How many electrodes does R1111M have on the left hemisphere and how many on the right hemisphere?

# %%
# Question 1.1
### YOUR CODE HERE

# %%
# Question 1.2
### YOUR CODE HERE

# %% [markdown]
# ## Question 2
# Now we will compare z-scored voltage traces for differing serial positions. (Use 'CH75')
#
# **1. Plot the ERPs for serial positions 1 and 4.**
#
# Generate ERPs for all the events in the first session (subject LTP093) for the first and fourth serial position separately (one ERP per serial position). Plot the voltage timeseries from 250 ms before the onset of the word until 1000 ms after the onset of the study word. In each figure panel mark study word onset.
#
# To carry out an ERP analysis on the voltage data, we must
#
# 1) Load the desired events.
#
# 2) Filter to only encoding events.
#
# 3) Get the voltage for all encoding events.
#
# 4) Baseline correct the voltage traces separately for each trace by establishing a "baseline" period of the signal from 250 ms before stimulus onset (word presentation) to 50ms before the stimulus onset (i.e., the "baseline" voltage), and then subtracting the average of the baseline from all values in the trace, and dividing all of these resulting values by the standard deviation of the baseline period. Baseline correction accounts for differing electrical characteristics of each channel, and for the fact that the electrical activity (or roughly speaking, state) of the brain will differ from event to event when the stimulus is presented. What we care about is how much the stimulus impacts the electrical activity of the brain relative to what it was just prior to the stimulus.
#
# 5) Filter events by serial position.
#
# 6) Plot the average voltage traces for the different groups of serial positions together on a single figure.
#     Compare the ERPs to the individual time series you plotted earlier. Is it easier to distinguish the serial positions of items when including data from all events?
#
# **2. Statistical Test: Does 'CH75' show a reliable difference**
#
# A. To test whether the 'CH75' shows a reliable difference, perform a Welch's t-test at each individual time point. How many of the 2000 time points are significantly different?
#
# B. Recompute the statistical significance of the difference between ERPs using the FDR correction method. How many time points are significant now?
#
# C. Comment on the difference between the two methods. Which is more conservative and why? How may the results differ with a larger sample size?

# %%
# Question 2.1
### YOUR CODE HERE

# %%
#Question 2.2
### YOUR CODE HERE 
**YOUR ANSWER HERE**
