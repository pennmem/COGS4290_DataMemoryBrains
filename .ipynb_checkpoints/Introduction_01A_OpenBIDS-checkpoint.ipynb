# %% [markdown]
# ## Understanding BIDS
# All EEG and iEEG data used in published studies by the Computational Memory Lab are also uploaded to OpenNeuro (https://openneuro.org/), a free and open platform for sharing MRI, PET, MEG, EEG, and iEEG data.
#
# We will begin this tutorial by explaining the Brain Imaging Data Structure (BIDS) format and how to load BIDS data using open source tools (mne-bids). See more about the BIDS format here: https://bids.neuroimaging.io/index.html, https://bidsschematools.readthedocs.io/en/latest/doc_to_schema.html.
#
# ### OpenBIDS Data Structure
#
# The BIDS format provides consistent folder organization and data formatting structures. Below is the general folder structure we will be using for this course. More detail will be provided in later introductions.
#
# <pre>
# BIDS_Dataset_Collection/
# ├── PEERS/ (study root)
# │    ├── sub-{subject_id}/
# │    │   └── ses-{session_id}/
# │    │       ├── beh/
# │    │       │   ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.json (Description of columns in the events data frame)
# │    │       │   └── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.tsv  (The actual events file)
# │    │       └── eeg/
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_eeg.bdf
# │    │           └── sub-{subject_id}_ses-{session_id}_task-{experiment}_events.tsv
# │    └── participants.tsv
# └── Other Studies
# </pre>
#
# First, create a BIDS_Dataset_Collection folder which will store all study folders downloaded from OpenNeuro. Next, we can set the bids_root which indicates the root of the study folder.

# %%
# imports
import pandas as pd; pd.set_option('display.max_columns', None)
from mne_bids import BIDSPath, read_raw_bids, get_entity_vals
import numpy as np
import os 
import mne
from ptsa.data.timeseries import TimeSeries

# set the bids_root
bids_root = "/data/LTP_BIDS/"

# %% [markdown]
# We can use the get_entity_vals functon from the mne_bids package to find all the subjects and tasks in the database. Once we have selected a subject, we can navigate to the root of its folder and use the get_entity_vals function to find all sessions and tasks associated with that subject.

# %% [markdown]
# ## Loading Scalp BIDS Data
#
# To load data in BIDS, first specify which study root, subject, session, and task you desire and add them as to the BIDSPath object. After building the base BIDSPath, you can update the path with the datatype, suffix, and extension fields to specify which file (behavioral or eeg) you want.
#
# Here are the BIDSPath fields you can manipulate:
# * root (str | Path: path to root of the study)
# * subject (str: subject id)
# * task (str: experiment id) (Scalp task examples: ltpFr2, valuecourier, vcbehonly, vffr)
# * session (str: session id)
# * datatype (str: type of data) (Examples: eeg (electrophysical), beh (behavioral))
# * suffix (str: type of data) (Examples: beh, events, electrodes, coordsystem, channels)
# * extension (str: file extension) (Examples: .tsv, .json, .edf, .bdf)

# %%
# plug in the subject, task, and session info into BIDSPath
# all inputs to BIDSPath should be strings so convert using the str() function

subject = "LTP606"
task = "valuecourier"
session = 0

base_path = BIDSPath(
                subject=subject,
                session=str(session),
                task=task,  
                root=bids_root
            )

# %% [markdown]
# ### Behavioral Data
# In the BIDS format, there are two locations where the behavioral data can be found. The first is stored in the beh (behavioral) folder.

# %%
# specify the behavioral folder by setting the datatype and suffix to "beh" and setting extension to ".tsv"
beh_path = base_path.copy().update(
                datatype="beh", 
                suffix="beh",
                extension=".tsv",
            )

# load it using read_csv
evs_beh = pd.read_csv(beh_path.fpath, sep="\t")
evs_beh[:5]
# Out:
#    mstime      trial_type stim_file  actualvalue  compensation  \
# 0       0  store mappings       NaN          NaN      8.461538
# 1    4142     VIDEO_START       NaN          NaN      8.461538
# 2  217121      VIDEO_STOP       NaN          NaN      8.461538
# 3  304052      SESS_START       NaN          NaN      8.461538
# 4  304098        TL_START       NaN          NaN      8.461538
#
#                                              eegfile  eogArtifact  \
# 0  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 1  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 2  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 3  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
# 4  /protocols/ltp/subjects/LTP606/experiments/Val...           -1
#
#      experiment  intruded  intrusion item  itemno  itemvalue  montage  \
# 0  ValueCourier       NaN        NaN  NaN     NaN        NaN        0
# 1  ValueCourier       NaN        NaN  NaN    -1.0        NaN        0
# 2  ValueCourier       NaN        NaN  NaN    -1.0        NaN        0
# 3  ValueCourier       NaN        NaN  NaN     NaN        NaN        0
# 4  ValueCourier       NaN        NaN  NaN     NaN        NaN        0
#
#    msoffset  multiplier  numingroupchosen phase  playerrotY     presX  presZ  \
# 0        -1    0.846154               4.0     1         NaN -4.949219   10.5
# 1        -1    0.846154               4.0     1         NaN -4.949219   10.5
# 2        -1    0.846154               4.0     1         NaN -4.949219   10.5
# 3        -1    0.846154               4.0     1         NaN -4.949219   10.5
# 4        -1    0.846154               4.0     1         NaN -4.949219   10.5
#
#    primacybuf protocol  recalled  rectime  recencybuf  serialpos  session  \
# 0         2.0      ltp       NaN      NaN         3.0        NaN        0
# 1         2.0      ltp       NaN      NaN         3.0        NaN        0
# 2         2.0      ltp       NaN      NaN         3.0        NaN        0
# 3         2.0      ltp       NaN      NaN         3.0        NaN        0
# 4         2.0      ltp       NaN      NaN         3.0        NaN        0
#
#   store  storeX  storeZ storepointtype subject  trial  valuerecall
# 0   NaN     NaN     NaN            NaN  LTP606      0          NaN
# 1   NaN     NaN     NaN            NaN  LTP606      0          NaN
# 2   NaN     NaN     NaN            NaN  LTP606      0          NaN
# 3   NaN     NaN     NaN            NaN  LTP606      0          NaN
# 4   NaN     NaN     NaN            NaN  LTP606      0          NaN

# %% [markdown]
# The second location is in the eeg folder.

# %%
# specify the eeg folder by setting the datatype to "eeg", suffix to "events", and setting extension to ".tsv"
eeg_path = base_path.copy().update(
                datatype="eeg", 
                suffix="events",
                extension=".tsv",
            )

# load it using read_csv
evs_eeg = pd.read_csv(eeg_path.fpath, sep="\t")
evs_eeg[:5]
# Out:
#         onset  duration      trial_type  sample stim_file  actualvalue  \
# 0   11.445312       NaN  store mappings   23440       NaN          NaN
# 1   15.586914       NaN     VIDEO_START   31922       NaN          NaN
# 2  228.548828       NaN      VIDEO_STOP  468068       NaN          NaN
# 3  315.473145       NaN      SESS_START  646089       NaN          NaN
# 4  315.519043       NaN        TL_START  646183       NaN          NaN
#
#    compensation                                            eegfile  \
# 0      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 1      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 2      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 3      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 4      8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
#
#    eogArtifact    experiment  intruded  intrusion item  itemno  itemvalue  \
# 0           -1  ValueCourier       NaN        NaN  NaN     NaN        NaN
# 1           -1  ValueCourier       NaN        NaN  NaN    -1.0        NaN
# 2           -1  ValueCourier       NaN        NaN  NaN    -1.0        NaN
# 3           -1  ValueCourier       NaN        NaN  NaN     NaN        NaN
# 4           -1  ValueCourier       NaN        NaN  NaN     NaN        NaN
#
#    montage  msoffset  multiplier  numingroupchosen phase  playerrotY  \
# 0        0        -1    0.846154               4.0     1         NaN
# 1        0        -1    0.846154               4.0     1         NaN
# 2        0        -1    0.846154               4.0     1         NaN
# 3        0        -1    0.846154               4.0     1         NaN
# 4        0        -1    0.846154               4.0     1         NaN
#
#       presX  presZ  primacybuf protocol  recalled  rectime  recencybuf  \
# 0 -4.949219   10.5         2.0      ltp       NaN      NaN         3.0
# 1 -4.949219   10.5         2.0      ltp       NaN      NaN         3.0
# 2 -4.949219   10.5         2.0      ltp       NaN      NaN         3.0
# 3 -4.949219   10.5         2.0      ltp       NaN      NaN         3.0
# 4 -4.949219   10.5         2.0      ltp       NaN      NaN         3.0
#
#    serialpos  session store  storeX  storeZ storepointtype subject  trial  \
# 0        NaN        0   NaN     NaN     NaN            NaN  LTP606      0
# 1        NaN        0   NaN     NaN     NaN            NaN  LTP606      0
# 2        NaN        0   NaN     NaN     NaN            NaN  LTP606      0
# 3        NaN        0   NaN     NaN     NaN            NaN  LTP606      0
# 4        NaN        0   NaN     NaN     NaN            NaN  LTP606      0
#
#    valuerecall
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# The only difference between the files is that the eeg/ieeg version describes time with the **onset** (start of event in seconds), **duration** (length of event in seconds), and **sample** (start of event in digital samples) variables and the behavioral version describes time with the **mstime** (start of event in milliseconds) variable. The differences are important for the packages to load EEG data as events, but you will not need to pay attention.

# %% [markdown]
# ### EEG Data
# To load EEG data, we first load the raw edf/bdf file and convert it into an mne.Epochs object.

# %%
# specify the datatype as "eeg"
eeg_path = base_path.copy().update(datatype="eeg")

# load raw data
raw = read_raw_bids(eeg_path)
raw
# Out:
# Extracting EDF parameters from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_events.tsv.
# Reading channel info from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_task-valuecourier_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/sub-LTP606/ses-0/eeg/sub-LTP606_ses-0_space-CapTrak_electrodes.tsv.
# /tmp/ipykernel_50390/2673785905.py:5: RuntimeWarning: The unit for channel(s) EXG5, EXG6, EXG7, EXG8 has changed from V to NA.
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/2673785905.py:5: RuntimeWarning: The unit for channel(s) Status has changed from NA to V.
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/2673785905.py:5: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG5', 'EXG6', 'EXG7', 'EXG8']
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/2673785905.py:5: RuntimeWarning: Not setting positions of 8 eog/misc channels found in montage:
# ['EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG5', 'EXG6', 'EXG7', 'EXG8']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(eeg_path)
# <RawEDF | sub-LTP606_ses-0_task-valuecourier_eeg.bdf, 137 x 10821632 (5284.0 s), ~154 kB, data not loaded>

# %%
# constants
REL_START, REL_STOP = 200, 3000
BUFFER_MS = 1000
WIDTH = 6

FREQS = np.logspace(np.log10(2), np.log10(100), 46)
NOTCH_BAND = (58., 62.)
BATCH_EVENTS = 64

# %%
# get events from raw data's header
events, event_id = mne.events_from_annotations(raw)

# set min and max of Epochs window
tmin = (-BUFFER_MS / 1000)
tmax = ((REL_STOP /1000 + BUFFER_MS / 1000))

# load into MNE Epochs object
epochs_mne = mne.Epochs(
    raw,
    events=events,                      # we can now load the events here
    event_id=event_id,             # we can also load the filtered events here
    tmin=tmin,
    tmax=tmax,
    baseline=None,                     # must set to None to ignore automatic baselining
    preload=True,
    event_repeated="merge",
)

epochs_mne
# Out:
# Used Annotations descriptions: ['FINAL_COMPENSATION', 'POINTER_ON', 'PRACTICE_DELIVERY_END', 'PRACTICE_DELIVERY_START', 'PRACTICE_VALUE_RECALL', 'PRACTICE_WORD', 'REC_START', 'REC_STOP', 'REC_WORD', 'REC_WORD_VV', 'SESS_END', 'SESS_START', 'TL_END', 'TL_START', 'TRIAL_END', 'TRIAL_START', 'VALUE_RECALL', 'VIDEO_START', 'VIDEO_STOP', 'WORD', 'store mappings']
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 10241 original time points ...
# 0 bad epochs dropped
# <Epochs |  240 events (all good), -1 – 4 s, baseline off, ~2.51 GB, data loaded,
#  'FINAL_COMPENSATION': 1
#  'POINTER_ON': 13
#  'PRACTICE_DELIVERY_END': 2
#  'PRACTICE_DELIVERY_START': 2
#  'PRACTICE_VALUE_RECALL': 2
#  'PRACTICE_WORD': 30
#  'REC_START': 7
#  'REC_STOP': 5
#  'REC_WORD': 29
#  'REC_WORD_VV': 3
#  and 12 more events ...>

# %% [markdown]
# ## Loading RAM BIDS Data
#
# The RAM dataset is the name for the CML intracranial eeg (ieeg) dataset, which is one of the largest ieeg datasets in the world.
#
# The folder structure for subjects with IEEGs implanted is different from the scalp. Scalp EEG contains a single edf file of monopolar electrodes and intracranial EEG contains two edf files for bipolar and monopolar electrodes and files describing the cooridnates, region, and other metadata for the electrodes.
#
# <pre>
# BIDS_Dataset_Collection/
# ├── PEERS/ (study root)
# │    ├── sub-{subject_id}/
# │    │   └── ses-{session_id}/
# │    │       ├── beh/
# │    │       │   ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.json (Description of columns in the events data frame)
# │    │       │   └── sub-{subject_id}_ses-{session_id}_task-{experiment}_beh.tsv  (The actual events file)
# │    │       └── ieeg/
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-bipolar_channels.tsv           (Pair data)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-bipolar_ieeg.edf               (Bipolar referenced signals)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-bipolar_ieeg.json               (Describes columns in pair data)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-monopolar_channels.tsv         (Contact data)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-monopolar_ieeg.edf             (Unreferenced signals)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_acq-monopolar_ieeg.json            (Columns in contact data)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_events.json                        (Description of columns in events file)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_events.tsv                         (Events file)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_space-{space_id}_coordsystem.json  (Indicates coordinate system and unit scale)
# │    │           ├── sub-{subject_id}_ses-{session_id}_task-{experiment}_space-{space_id}_electrodes.json   (Describes columns in electrodes data)
# │    │           └── sub-{subject_id}_ses-{session_id}_task-{experiment}_space-{space_id}_electrodes.tsv    (Electrodes dataframe with full description)
# │    └── participants.tsv
# └── Other Studies
# </pre>
#
# The BIDSPath fields for RAM is the same as scalp, except with the additional acquisition field, which indicates whether the file has monopolar or bipolar data, and space, which lists hte iEEG coordinate system. Bipolar electrode data are differential, localized voltage measurements between pairs of electrodes, highlighting local neural activity rather than broad, reference-based potentials.
#
# Fields:
# * root (str | Path: path to root of the study)
# * subject (str: subject id)
# * task (str: experiment id) (Scalp task examples: ltpFr2, valuecourier, vcbehonly, vffr)
# * session (str: session id)
# * datatype (str: type of data) (Examples: ieeg (electrophysical), beh (behavioral))
# * suffix (str: type of data) (Examples: beh, events, electrodes, channels, coordsystem)
# * extension (str: file extension) (Examples: .tsv, .json, .edf, .bdf)
# * acquisition (str: type of eeg acquisition ) (bipolar or monopolar)
# * space (str: iEEG coordinate system) (MNI152NLin6ASym, Talarich)

# %%
# set the bids_root
bids_root = "/data/LTP_BIDS/FR1/"

# plug in the subject, task, and session info into BIDSPath 
# all inputs to BIDSPath should be strings so convert using the str() function
subject = "R1111M"
task = "FR1"
session = 0

base_path = BIDSPath(
    subject=subject,
    session=str(session),
    task=task,
    root=bids_root,
)

# %% [markdown]
# ### Loading Monopolar EEG data

# %%
# specify the datatype as "ieeg" and acquisition to "monopolar"
acq = "monopolar"        
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", acquisition="monopolar", suffix="ieeg", extension=".edf")

# load raw data
raw = read_raw_bids(eeg_path)

# constants
REL_START, REL_STOP = 200, 3000
BUFFER_MS = 1000
WIDTH = 6

FREQS = np.logspace(np.log10(2), np.log10(100), 46)
NOTCH_BAND = (58., 62.)
BATCH_EVENTS = 64

# get events from raw data's header
events, event_id = mne.events_from_annotations(raw)

# set min and max of Epochs window
tmin = (-BUFFER_MS / 1000)
tmax = ((REL_STOP /1000 + BUFFER_MS / 1000))

# load into MNE Epochs object
epochs_mne = mne.Epochs(
    raw,
    events=events,                      # we can now load the events here
    event_id=event_id,             # we can also load the filtered events here
    tmin=tmin,
    tmax=tmax,
    baseline=None, 
    preload=True,
    event_repeated="merge",
)

epochs_mne
# Out:
# Extracting EDF parameters from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_acq-monopolar_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_events.tsv.
# Reading channel info from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_acq-monopolar_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_space-MNI152NLin6ASym_electrodes.tsv.
# Used Annotations descriptions: ['COUNTDOWN_END', 'COUNTDOWN_START', 'DISTRACT_END', 'DISTRACT_START', 'ORIENT', 'PRACTICE_DISTRACT_END', 'PRACTICE_DISTRACT_START', 'PRACTICE_REC_END', 'PRACTICE_REC_START', 'PRACTICE_WORD', 'PROB', 'REC_END', 'REC_START', 'REC_WORD', 'SESS_START', 'START', 'STOP', 'TRIAL', 'WORD']
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 722 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 722 events and 2501 original time points ...
# /tmp/ipykernel_50390/1310487713.py:7: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/1310487713.py:7: RuntimeWarning: MNI152NLin6ASym is not an MNE-Python coordinate frame for IEEG data and so will be set to 'unknown'
#   raw = read_raw_bids(eeg_path)
# 1 bad epochs dropped
# <Epochs |  721 events (all good), -1 – 4 s, baseline off, ~1.34 GB, data loaded,
#  'COUNTDOWN_END': 25
#  'COUNTDOWN_START': 2
#  'DISTRACT_END': 24
#  'DISTRACT_START': 7
#  'ORIENT': 24
#  'PRACTICE_DISTRACT_END': 1
#  'PRACTICE_REC_END': 1
#  'PRACTICE_REC_START': 1
#  'PRACTICE_WORD': 12
#  'PROB': 82
#  and 11 more events ...>

# %% [markdown]
# ### Loading Bipolar EEG data

# %%
# specify the datatype as "ieeg" and acquisition to "bipolar"
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", acquisition="bipolar", suffix="ieeg", extension=".edf")

# load raw data
raw = read_raw_bids(eeg_path)

# constants
REL_START, REL_STOP = 200, 3000
BUFFER_MS = 1000
WIDTH = 6

FREQS = np.logspace(np.log10(2), np.log10(100), 46)
NOTCH_BAND = (58., 62.)
BATCH_EVENTS = 64

# get events from raw data's header
events, event_id = mne.events_from_annotations(raw)

# set min and max of Epochs window
tmin = (-BUFFER_MS / 1000)
tmax = ((REL_STOP /1000 + BUFFER_MS / 1000))

# load into MNE Epochs object
epochs_mne = mne.Epochs(
    raw,
    events=events,                      # we can now load the events here
    event_id=event_id,             # we can also load the filtered events here
    tmin=tmin,
    tmax=tmax,
    baseline=None, 
    preload=True,
    event_repeated="merge",
)

epochs_mne
# Out:
# Extracting EDF parameters from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_acq-bipolar_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_events.tsv.
# Reading channel info from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_acq-bipolar_channels.tsv.
# Reading electrode coords from /data/LTP_BIDS/FR1/sub-R1111M/ses-0/ieeg/sub-R1111M_ses-0_task-FR1_space-MNI152NLin6ASym_electrodes.tsv.
# Used Annotations descriptions: ['COUNTDOWN_END', 'COUNTDOWN_START', 'DISTRACT_END', 'DISTRACT_START', 'ORIENT', 'PRACTICE_DISTRACT_END', 'PRACTICE_DISTRACT_START', 'PRACTICE_REC_END', 'PRACTICE_REC_START', 'PRACTICE_WORD', 'PROB', 'REC_END', 'REC_START', 'REC_WORD', 'SESS_START', 'START', 'STOP', 'TRIAL', 'WORD']
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 722 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 722 events and 2501 original time points ...
# /tmp/ipykernel_50390/260424670.py:6: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/260424670.py:6: RuntimeWarning: MNI152NLin6ASym is not an MNE-Python coordinate frame for IEEG data and so will be set to 'unknown'
#   raw = read_raw_bids(eeg_path)
# /tmp/ipykernel_50390/260424670.py:6: RuntimeWarning: DigMontage is only a subset of info. There are 141 channel positions not present in the DigMontage. The channels missing from the montage are:
#
# ['LPOG1-LPOG9', 'LPOG1-LPOG2', 'LPOG2-LPOG10', 'LPOG2-LPOG3', 'LPOG3-LPOG4', 'LPOG3-LPOG11', 'LPOG4-LPOG5', 'LPOG4-LPOG12', 'LPOG5-LPOG6', 'LPOG5-LPOG13', 'LPOG6-LPOG7', 'LPOG6-LPOG14', 'LPOG7-LPOG8', 'LPOG7-LPOG15', 'LPOG8-LPOG16', 'LPOG9-LPOG17', 'LPOG9-LPOG10', 'LPOG10-LPOG11', 'LPOG10-LPOG18', 'LPOG11-LPOG12', 'LPOG11-LPOG19', 'LPOG12-LPOG13', 'LPOG12-LPOG20', 'LPOG13-LPOG14', 'LPOG13-LPOG21', 'LPOG14-LPOG15', 'LPOG14-LPOG22', 'LPOG15-LPOG16', 'LPOG15-LPOG23', 'LPOG16-LPOG24', 'LPOG17-LPOG25', 'LPOG17-LPOG18', 'LPOG18-LPOG19', 'LPOG18-LPOG26', 'LPOG19-LPOG20', 'LPOG19-LPOG27', 'LPOG20-LPOG21', 'LPOG20-LPOG28', 'LPOG21-LPOG29', 'LPOG21-LPOG22', 'LPOG22-LPOG30', 'LPOG22-LPOG23', 'LPOG23-LPOG24', 'LPOG23-LPOG31', 'LPOG24-LPOG32', 'LPOG25-LPOG26', 'LPOG25-LPOG33', 'LPOG26-LPOG27', 'LPOG26-LPOG34', 'LPOG27-LPOG28', 'LPOG27-LPOG35', 'LPOG28-LPOG36', 'LPOG28-LPOG29', 'LPOG29-LPOG30', 'LPOG29-LPOG37', 'LPOG30-LPOG31', 'LPOG30-LPOG38', 'LPOG31-LPOG39', 'LPOG31-LPOG32', 'LPOG32-LPOG40', 'LPOG33-LPOG41', 'LPOG33-LPOG34', 'LPOG34-LPOG35', 'LPOG34-LPOG42', 'LPOG35-LPOG36', 'LPOG35-LPOG43', 'LPOG36-LPOG37', 'LPOG36-LPOG44', 'LPOG37-LPOG45', 'LPOG37-LPOG38', 'LPOG38-LPOG46', 'LPOG38-LPOG39', 'LPOG39-LPOG40', 'LPOG39-LPOG47', 'LPOG40-LPOG48', 'LPOG41-LPOG49', 'LPOG41-LPOG42', 'LPOG42-LPOG43', 'LPOG42-LPOG50', 'LPOG43-LPOG44', 'LPOG43-LPOG51', 'LPOG44-LPOG45', 'LPOG44-LPOG52', 'LPOG45-LPOG46', 'LPOG45-LPOG53', 'LPOG46-LPOG47', 'LPOG46-LPOG54', 'LPOG47-LPOG55', 'LPOG47-LPOG48', 'LPOG48-LPOG56', 'LPOG49-LPOG50', 'LPOG49-LPOG57', 'LPOG50-LPOG58', 'LPOG50-LPOG51', 'LPOG51-LPOG59', 'LPOG51-LPOG52', 'LPOG52-LPOG60', 'LPOG52-LPOG53', 'LPOG53-LPOG61', 'LPOG53-LPOG54', 'LPOG54-LPOG55', 'LPOG54-LPOG62', 'LPOG55-LPOG63', 'LPOG55-LPOG56', 'LPOG56-LPOG64', 'LPOG57-LPOG58', 'LPOG58-LPOG59', 'LPOG59-LPOG60', 'LPOG60-LPOG61', 'LPOG61-LPOG62', 'LPOG62-LPOG63', 'LPOG63-LPOG64', 'LOAD1-LOAD2', 'LOAD2-LOAD3', 'LOAD3-LOAD4', 'LOPD1-LOPD2', 'LOPD2-LOPD3', 'LOPD3-LOPD4', 'LOS1-LOS2', 'LOS2-LOS3', 'LOS3-LOS4', 'LOS4-LOS5', 'LOS5-LOS6', 'LOS6-LOS7', 'LOS7-LOS8', 'LTS1-LTS2', 'LTS2-LTS3', 'LTS3-LTS4', 'LTS4-LTS5', 'LTS5-LTS6', 'LTS6-LTS7', 'LTS7-LTS8', 'LAS1-LAS2', 'LAS2-LAS3', 'LAS3-LAS4', 'LPS1-LPS2', 'LPS2-LPS3', 'LPS3-LPS4', 'LTD1-LTD2', 'LTD2-LTD3', 'LTD3-LTD4'].
#
# Consider using inst.rename_channels to match the montage nomenclature, or inst.set_channel_types if these are not EEG channels, or use the on_missing parameter if the channel positions are allowed to be unknown in your analyses.
#   raw = read_raw_bids(eeg_path)
# 1 bad epochs dropped
# <Epochs |  721 events (all good), -1 – 4 s, baseline off, ~1.89 GB, data loaded,
#  'COUNTDOWN_END': 25
#  'COUNTDOWN_START': 2
#  'DISTRACT_END': 24
#  'DISTRACT_START': 7
#  'ORIENT': 24
#  'PRACTICE_DISTRACT_END': 1
#  'PRACTICE_REC_END': 1
#  'PRACTICE_REC_START': 1
#  'PRACTICE_WORD': 12
#  'PROB': 82
#  and 11 more events ...>

# %% [markdown]
# ### Loading Electrodes, Coordsystem, and Channel data

# %%
# electrodes 
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", suffix="electrodes", space="MNI152NLin6ASym", extension=".tsv")
pd.read_csv(eeg_path.fpath, sep="\t")
# Out:
#      name        x          y          z  size group hemisphere   type  \
# 0   LPOG1 -67.9554 -20.436300 -26.318920  -999  LPOG          L   grid
# 1   LPOG2 -71.3723 -19.887300 -17.033223  -999  LPOG          L   grid
# 2   LPOG3 -69.4694 -16.873900  -5.837007  -999  LPOG          L   grid
# 3   LPOG4 -68.4177 -13.619100   6.599195  -999  LPOG          L   grid
# 4   LPOG5 -68.5695 -14.288000  16.220750  -999  LPOG          L   grid
# ..    ...      ...        ...        ...   ...   ...        ...    ...
# 95   LPS4 -60.3150   0.724204 -33.789406  -999   LPS          L  strip
# 96   LTD1 -24.4314 -20.139100 -23.616084  -999   LTD          L  depth
# 97   LTD2 -28.6866 -18.553800 -24.592941  -999   LTD          L  depth
# 98   LTD3 -33.2518 -18.690900 -25.448912  -999   LTD          L  depth
# 99   LTD4 -36.8589 -16.779900 -25.648431  -999   LTD          L  depth
#
#       tal.x     tal.y     tal.z                       wb.region  \
# 0  -66.7592 -20.37470 -21.06940                             NaN
# 1  -68.5270 -19.30560 -13.11050                             NaN
# 2  -67.0028 -17.99460  -3.26183                             NaN
# 3  -62.8222 -17.49650   6.35027                             NaN
# 4  -60.2654 -16.09750  16.38480                             NaN
# ..      ...       ...       ...                             ...
# 95 -59.5567  -3.04176 -28.33260                             NaN
# 96 -23.8723 -23.65220 -19.49340  Left PHG parahippocampal gyrus
# 97 -28.2112 -20.97920 -19.44620      Left Cerebral White Matter
# 98 -33.5565 -19.32430 -18.68380  Left PHG parahippocampal gyrus
# 99 -37.8955 -16.65110 -18.63680  Left PHG parahippocampal gyrus
#
#           ind.region stein.region
# 0     middletemporal          NaN
# 1     middletemporal          NaN
# 2     middletemporal          NaN
# 3   superiortemporal          NaN
# 4        postcentral          NaN
# ..               ...          ...
# 95    middletemporal          NaN
# 96   parahippocampal      Left EC
# 97   parahippocampal  Left MTL WM
# 98   parahippocampal     Left PRC
# 99   parahippocampal     Left PRC
#
# [100 rows x 14 columns]

# %%
import json
# coordsystem 
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", suffix="coordsystem", space="MNI152NLin6ASym", extension=".json")
with open(eeg_path.fpath, "r") as f:
    coordsystem = json.load(f)
coordsystem
# Out:
# {'iEEGCoordinateSystem': 'MNI152NLin6ASym', 'iEEGCoordinateUnits': 'mm'}

# %%
# monopolar channels 
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", suffix="channels", acquisition="monopolar", extension=".tsv")
pd.read_csv(eeg_path.fpath, sep="\t")
# Out:
#      name  type units  low_cutoff  high_cutoff group  sampling_frequency  \
# 0   LPOG1  ECOG     V         NaN          NaN  LPOG                 500
# 1   LPOG2  ECOG     V         NaN          NaN  LPOG                 500
# 2   LPOG3  ECOG     V         NaN          NaN  LPOG                 500
# 3   LPOG4  ECOG     V         NaN          NaN  LPOG                 500
# 4   LPOG5  ECOG     V         NaN          NaN  LPOG                 500
# ..    ...   ...   ...         ...          ...   ...                 ...
# 95   LPS4  ECOG     V         NaN          NaN   LPS                 500
# 96   LTD1  SEEG     V         NaN          NaN   LTD                 500
# 97   LTD2  SEEG     V         NaN          NaN   LTD                 500
# 98   LTD3  SEEG     V         NaN          NaN   LTD                 500
# 99   LTD4  SEEG     V         NaN          NaN   LTD                 500
#
#    description  notch
# 0         grid    NaN
# 1         grid    NaN
# 2         grid    NaN
# 3         grid    NaN
# 4         grid    NaN
# ..         ...    ...
# 95       strip    NaN
# 96       depth    NaN
# 97       depth    NaN
# 98       depth    NaN
# 99       depth    NaN
#
# [100 rows x 9 columns]

# %%
# bipolar channels 
eeg_path = base_path.copy()
eeg_path.update(datatype="ieeg", suffix="channels", acquisition="bipolar", extension=".tsv")
pd.read_csv(eeg_path.fpath, sep="\t")
# Out:
#              name  type units  low_cutoff  high_cutoff reference group  \
# 0     LPOG1-LPOG9  ECOG     V         NaN          NaN   bipolar  LPOG
# 1     LPOG1-LPOG2  ECOG     V         NaN          NaN   bipolar  LPOG
# 2    LPOG2-LPOG10  ECOG     V         NaN          NaN   bipolar  LPOG
# 3     LPOG2-LPOG3  ECOG     V         NaN          NaN   bipolar  LPOG
# 4     LPOG3-LPOG4  ECOG     V         NaN          NaN   bipolar  LPOG
# ..            ...   ...   ...         ...          ...       ...   ...
# 136     LPS2-LPS3  ECOG     V         NaN          NaN   bipolar   LPS
# 137     LPS3-LPS4  ECOG     V         NaN          NaN   bipolar   LPS
# 138     LTD1-LTD2  SEEG     V         NaN          NaN   bipolar   LTD
# 139     LTD2-LTD3  SEEG     V         NaN          NaN   bipolar   LTD
# 140     LTD3-LTD4  SEEG     V         NaN          NaN   bipolar   LTD
#
#      sampling_frequency description  notch
# 0                   500        grid    NaN
# 1                   500        grid    NaN
# 2                   500        grid    NaN
# 3                   500        grid    NaN
# 4                   500        grid    NaN
# ..                  ...         ...    ...
# 136                 500       strip    NaN
# 137                 500       strip    NaN
# 138                 500       depth    NaN
# 139                 500       depth    NaN
# 140                 500       depth    NaN
#
# [141 rows x 10 columns]

# %% [markdown]
# If loading BIDS data seems complicated...it is! That's why we have created the **BIDSReader** package which simplifies loading BIDs data and replicates the syntax of CMLReader, the data reader package for the CML format. You will learn how to use **BIDSReader** in the next Introduction.
